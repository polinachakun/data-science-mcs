# %% [markdown]
# # Exercise 01
#
# ## Task 1 - College
#
# - a) Load the `College.csv` dataset into a `pandas` `DataFrame`.
# - b) Rename the first column from `Unnamed: 0` to `College`.
# - c) Use the [`describe`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html) method to get a summary of the data.
# - d) Create a scatterplot matrix of the columns `[Top10Perc, Apps, Enroll]`. You can use the [`pd.plotting.scatter_matrix`](https://pandas.pydata.org/docs/reference/api/pandas.plotting.scatter_matrix.html) function.
#     - d1) 💬 Discuss in pairs: What can you observe from the scatterplot matrix?
#     - d2) 💬 Discuss in pairs: Can you see any relationships between the variables? Do any of them seem to be correlated? How can you tell from the plot?
# - e) Create a boxplot to create side-by-side boxplots of `Outstate` versus `Private`. You can use the [`boxplot()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.boxplot.html) method.
# - f) Create a new qualitative variable, called `Elite`, by **binning** the `Top10Perc` variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.
#     - f1) Use the [`value_counts()`](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html) method of the `Elite` variable to see how many elite universities there are.
#     - f2) Use the `boxplot()` method to create a boxplot of `Outstate` versus `Elite`.
# - g) Produce some histograms with different numbers of bins for a few of the quantitative variables. You can use the [`plot.hist()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.hist.html) method. You may find the `subplots` argument useful.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Solution a)

# %%
df_college = pd.read_csv('College.csv')
df_college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# Solution b)

# %%
df_college.rename(columns={'Unnamed: 0': 'College'}, inplace=True)
df_college
# Out:
#                             College Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# Solution c)

# %%
summary = df_college.describe()
print(summary)
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# Solution d)

# %%
pd.plotting.scatter_matrix(df_college[['Top10perc', 'Apps', 'Enroll']], figsize=(10, 8))
plt.show()

# %% [markdown]
# Solution d1) and d2)

# %% [markdown]
# Solution e)

# %%
df_college.boxplot(column='Outstate', by='Private', grid=True)
plt.show()

# %% [markdown]
# Solution f)

# %%
import numpy as np
df_college['Elite'] = np.where(df_college['Top10perc'] > 50, 'Yes', 'No')
# Out:
#                             College Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# Solution f1)

# %%
elite_counts = df_college['Elite'].value_counts()
print(elite_counts)
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %% [markdown]
# Solution f2)

# %%
df_college.boxplot(column='Outstate', by='Elite', grid=True) # Remove the default title to avoid overlap
plt.show()

# %% [markdown]
# Solution g)

# %%
df_college[['Apps', 'Enroll', 'Outstate']].hist(bins=15, figsize=(10, 8), grid=False)
plt.show()

df_college[['Apps', 'Enroll', 'Outstate']].hist(bins=30, figsize=(10, 8), grid=False)
plt.show()

# %% [markdown]
# # Task 2 - Pokemon
#
# - a) Load the `pokemon.csv` dataset into a `pandas` `DataFrame`.
# - b) Parse the `'abilities'` column into a list of strings.
# - c) Use the [`explode`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.explode.html) method to create a new row for each ability of a Pokemon.
# - d) Find the most common and rarest ability.
# - e) Find the most common and rarest ability for each Generation.

# %% [markdown]
# Solution a)

# %%
df_pokemon = pd.read_csv('pokemon.csv')
df_pokemon
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %% [markdown]
# Solution b)

# %%
df_pokemon['abilities'] = df_pokemon['abilities'].apply(lambda x: x.strip('[]').replace("'", "").split(', '))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_pokemon['abilities'] = df_pokemon['abilities'].apply(lambda x: x.strip('[]').replace("'", "").split(', '))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# ...

# %% [markdown]
# Solution c)

# %%
df_exploded = df_pokemon.explode('abilities')

# %% [markdown]
# Solution d)

# %%
most_common_ability = df_exploded['abilities'].value_counts().idxmax()
rarest_ability = df_exploded['abilities'].value_counts().idxmin()

print(f"Most common ability: {most_common_ability}")
print(f"Rarest ability: {rarest_ability}")
# Out:
# Most common ability: Sturdy
# Rarest ability: Psychic Surge

# %% [markdown]
# Solution e)

# %%
# Assuming 'generation' is a column in the dataset that indicates the Pokemon's generation.
generation_ability_counts = df_exploded.groupby('generation')['abilities'].value_counts()

# Finding the most common and rarest ability per generation
most_common_per_gen = generation_ability_counts.groupby('generation').idxmax()
rarest_per_gen = generation_ability_counts.groupby('generation').idxmin()

print("\nMost common ability for each Generation:")
print(most_common_per_gen)

print("\nRarest ability for each Generation:")
print(rarest_per_gen)
# Out:
# Most common ability for each Generation:
# generation
# 1     (1, Swift Swim)
# 2     (2, Early Bird)
# 3     (3, Swift Swim)
# 4       (4, Levitate)
# 5          (5, Swarm)
# 6          (6, Frisk)
# 7    (7, Beast Boost)
# Name: count, dtype: object
#
# Rarest ability for each Generation:
# generation
# 1    (1, Adaptability)
# 2        (2, Analytic)
# 3        (3, Air Lock)
# 4    (4, Adaptability)
# 5    (5, Adaptability)
# 6      (6, Aura Break)
# 7         (7, Battery)
# Name: count, dtype: object

# %% [markdown]
# # Task 3 - Flexible and inflexible models
#
# For the following scenarios, indicate whether we would generall expect the performance of a flexible statistical learning method to be better or worse than an inflexible method.
# You can test your intuition by simulating the scenarios. It is suggested you run the cells only after you think about the answer (to not spoil the exercise for yourself :) )
#
# - 🧩: Form four groups, one for each scenario. Discuss the scenario within your group.
#     - Afterwards, form four new groups, such that there is at least one member of each original group in each new group.
#     - Present your scenario in the new group and discuss the answer.
#     - *Hint*: You can simulate the scenarios with code to test your intuition!
#
# The scenarios are:
# - a) Large sample size $n$, but a small number of predictors $p$
# - b) Small sample size $n$, but a large number of predictors $p$
# - c) The relationship between the predictors and response is highly non-linear
# - d) The variance of the error terms, i.e. noise, is extremely high.
